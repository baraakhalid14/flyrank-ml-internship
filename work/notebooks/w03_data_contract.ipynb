# %% [markdown]
# <a href="https://colab.research.google.com/github/baraakhalid14/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/baraakhalid14/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
"""
One row represents one search result for one user's search query.

The analysis uses the available warehouse data from 2025-01-27 to 2026-06-30. For the verification queries, I will use the mid-panel month 2026-03.
"""
# Out:
# "\nOne row represents one search result for one user's search query.\n\nThe analysis uses the available warehouse data from 2025-01-27 to 2026-06-30. For the verification queries, I will use the mid-panel month 2026-03.\n"

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
"""
Features:
- engagement_rate: known before ranking and measures user interaction.
- scroll_rate: known before ranking and measures how far users scroll.
- ai_traffic_pct: known before ranking and measures the percentage of AI-generated traffic.
- trend_pct: known before ranking and represents recent performance trends.
- gsc_avg_position: used only when gsc_data_available IS TRUE.

Label / Proxy:
Observed search engagement is used as the relevance proxy. Higher engagement suggests higher relevance.

Context:
client_id, content_id, query_hash, and report_date are used for grouping, joining, filtering, and splitting the data. They are not model features.

Excluded:
Client names, URLs, and raw query text are excluded because they contain private information.
Future clicks, future traffic, and future engagement metrics are excluded because they would cause data leakage.
Rows where gsc_data_available is not TRUE are excluded from GSC-based analysis.
"""
# Out:
# '\nFeatures:\n- engagement_rate: known before ranking and measures user interaction.\n- scroll_rate: known before ranking and measures how far users scroll.\n- ai_traffic_pct: known before ranking and measures the percentage of AI-generated traffic.\n- trend_pct: known before ranking and represents recent performance trends.\n- gsc_avg_position: used only when gsc_data_available IS TRUE.\n\nLabel / Proxy:\nObserved search engagement is used as the relevance proxy. Higher engagement suggests higher relevance.\n\nContext:\nclient_id, content_id, query_hash, and report_date are used for grouping, joining, filtering, and splitting the data. They are not model features.\n\nExcluded:\nClient names, URLs, and raw query text are excluded because they contain private information.\nFuture clicks, future traffic, and future engagement metrics are excluded because they would cause data leakage.\nRows where gsc_data_available is not TRUE are excluded from GSC-based analysis.\n'

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
availability_query = """
SELECT
    COUNT(*) AS total_rows,
    COUNTIF(gsc_data_available IS TRUE) AS available_rows,
    COUNTIF(gsc_data_available IS NOT TRUE) AS unavailable_rows
FROM `your_table`
WHERE report_date >= DATE '2026-03-01'
  AND report_date < DATE '2026-04-01'
"""

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
"""
This dataset cannot prove that user engagement is caused only by search relevance.

Some clients have shorter histories than others, and some early rows do not contain complete Google Search Console data. GSC-based features should only be used when gsc_data_available IS TRUE.

The query-level table contains overlapping 90-day windows, so nearby observations are not completely independent.

Results from one selected month may not generalize to all clients or future time periods.

Private information such as client names, URLs, and raw query text is intentionally excluded.
"""
# Out:
# '\nThis dataset cannot prove that user engagement is caused only by search relevance.\n\nSome clients have shorter histories than others, and some early rows do not contain complete Google Search Console data. GSC-based features should only be used when gsc_data_available IS TRUE.\n\nThe query-level table contains overlapping 90-day windows, so nearby observations are not completely independent.\n\nResults from one selected month may not generalize to all clients or future time periods.\n\nPrivate information such as client names, URLs, and raw query text is intentionally excluded.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
